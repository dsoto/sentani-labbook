# %%
# %matplotlib inline
import numpy as np
from scipy.stats import binom
import matplotlib.pyplot as plt

# %%
p = 0.75
n = 200
x = np.arange(0, n, 1)
plt.plot(x/n, binom.pmf(x, n, p))
n = 100
x = np.arange(0,xmax,1)
plt.plot(x/n, binom.pmf(x, n, p))
plt.xlabel('Fraction of Households with Appliance')
plt.ylabel('Probability Density')
